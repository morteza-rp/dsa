# %%
import math
print("Integer Operations")
a, b = 1, 2
# %timeit -r 3 -n 100 a + b
# %timeit -r 3 -n 100 a * b
# %timeit -r 3 -n 100 a // b
# Out:
# Integer Operations
# 73.7 ns ± 2.36 ns per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 130 ns ± 10 ns per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 135 ns ± 11.6 ns per loop (mean ± std. dev. of 3 runs, 100 loops each)

# %%
# %matplotlib inline
from matplotlib.pyplot import *
rcParams.update({'font.size': 10, 'font.family': 'serif', 'lines.linewidth': 3})

def plot1(max_n):
    figure(figsize=(10, 5))

    xlabel("N")
    x = range(1, max_n+1)

    def f(n): return 1.0/6*n**3 + 20*n + 16
    y = [f(n) for n in x]
    plot(x, y, 'r', label='1/6n^3 + 20n + 16')

    def f(n): return 1.0/6*n**3 + 100*n**(4.0/3) + 56
    y = [f(n) for n in x]
    plot(x, y, 'g', label='1/6n^3 + 100n^(4/3) + 56')

    def f(n): return 1.0/6*n**3 - 1.0/2*n**2 + 1.0/3*n
    y = [f(n) for n in x]
    plot(x, y, 'b', label='1/6n^3 - 1/2n^2 + 1/3n')

    y = [1.0/6*n**3 for n in x]
    plot(x, y, 'k', label='1/6n^3')

    legend(loc=2)

    show()

plot1(500)
